# %% [markdown]
# ## Reaktivita/Reaktívnosť (Reactive Mode)
# RxPy

# %%
dpw_farba = "cierna"

# %%
print(dpw_farba)
# Out:
# cierna

# %%
import datetime
dtp_nastup_praca = datetime.date(2025, 03, 07)

# %%
print(dtp_nastup_praca)
# Out:
# 2025-03-07

# %%
# wxwidget

# %%
sld_hlasitost = 90

# %%
print(sld_hlasitost)
# Out:
# 90

# %%
txt_meno = "Ivana"

# %%
print(f"Ahoj {txt_meno}")
# Out:
# Ahoj Ivana

# %%
ckb_gdpr = False

# %%
print(f"Mám suhlas: {ckb_gdpr}")
# Out:
# Mám suhlas: False
