# %% [markdown]
# # 🐍Python Spracovanie a Vizualizácia Dát

# %% [markdown]
# ## I. ⚒️ Prehľad knižníc, balíčkov

# %% [markdown]
# 🐼 Pandas - nástroj na manipuláciu s tabuľkovými údajmi v Pythone. Je to obrovská knižnica, ale ak poznáte správne metódy, môžeme vytvoriť výkonnú analýzu.
#
# 📊 Matplotlib - grafická knižnica s rôznymi grafmi a vizualizáciami. V spojení s Pandas a Jupyter môžeme rýchlo získať prehľad o našich údajoch.
#
# 🚀 Numpy - knižnica jazyka Python, ktorá poskytuje infraštruktúru pre prácu s vektormi, maticami a všeobecne viacrozmernými poliami.
#
# Image
# CountryInfo
# BeautifulSoup
# CurrencyRates
#
# https://www.python.org/about/apps/

# %% [markdown]
# ## II. Informácie o krajinách

# %%
# !pip install countryinfo
# !pip show countryinfo
from countryinfo import CountryInfo

tmp = input("Zadaj nazov krajiny: ")

krajina = CountryInfo(tmp)
print("Hlavne mesto: ", krajina.capital())
print("Meny: ", krajina.currencies())
print("Jazyky: ", krajina.languages())
print("Hranice: ", krajina.borders())
print("Ine nazvy: ", krajina.alt_spellings())
# Out:
# Zadaj nazov krajiny: Austria
# Hlavne mesto:  Vienna
# Meny:  ['EUR']
# Jazyky:  ['de']
# Hranice:  ['CZE', 'DEU', 'HUN', 'ITA', 'LIE', 'SVK', 'SVN', 'CHE']
# Ine nazvy:  ['AT', 'Österreich', 'Osterreich', 'Oesterreich']

# %% [markdown]
# ## III. Vizualizácie Dát (Matplotlib) 📊

# %%
try:
    import matplotlib
    from matplotlib import pyplot as plt
    import numpy as np
    import pandas as pd
#     import CurrencyRates
    
    print("Moduly boli nacitane...")
    print("Verzia Matplotlib -->", matplotlib.__version__)
    print("Verzia Numpy -->", numpy.__version__)
    print("Verzia Pandas -->", pandas.__version__)
    
except:
    print("Moduly neboli nacitane...")
    
finally:
    print("Sme v casti finally")
# Out:
# Moduly boli nacitane...
# Verzia Matplotlib --> 3.4.3
# Verzia Numpy --> 1.20.3
# Verzia Pandas --> 1.3.4
# Sme v casti finally

# %% [markdown]
# ## IV. Čiarový Graf

# %%
try:
    from matplotlib import pyplot as plt
    import numpy as np
    import pandas as pd
    import math

    # Array (Pole) podobna struktura ako List (Zoznam)
    x = np.arange(0, 5);
    print(x)
    # ** // ^ (XOR) %
    y = x ^ 2;
#     y = math.pow(x, 2)
    
    plt.title("Ciarovy graf XY")
    plt.xlabel("X os")
    plt.ylabel("Y os")
    plt.plot(x, y)
    
    plt.annotate(xy = [1, 3.5], text = "Popis 1")
    plt.annotate(xy = [2.5, 2], text = "Popis 2")
    
except:
    print("Moduly neboli nacitane...")
    
finally:
    print("Sme v casti finally")
# Out:
# [0 1 2 3 4]
# Sme v casti finally

# %% [markdown]
# ## V. Bodový Graf (XY závislosť)

# %%
try:
    from matplotlib import pyplot as plt
    import numpy as np
    import pandas as pd
    import math

    # Array (Pole) podobna struktura ako List (Zoznam)
    x = np.arange(0, 5);
    s = [5, 10, 20, 40]
    print(x)
    # ** // ^ (XOR) %
    y = x ** 2;
#     y = math.pow(x, 2)
    
    # RGB
    # CMYK
    # HSV, HSB, HSL
    
    # x - krizik, o - gulicka, s - stvorec, d - disc, p - pentauholnik
    
    
    plt.title("Bodovy graf XY")
    plt.xlabel("X os")
    plt.ylabel("Y os")
    plt.plot(x, y, s)
    
    plt.annotate(xy = [1, 3.5], text = "Popis 1")
    plt.annotate(xy = [2.5, 2], text = "Popis 2")
    
    plt.show()
    
except:
    print("Moduly neboli nacitane...")
    
finally:
    print("Sme v casti finally")
# Out:
# [0 1 2 3 4]
# Sme v casti finally

# %% [markdown]
# ## VI. Bodové Grafy Kombinacie (XY závislosť)

# %%
try:
    from matplotlib import pyplot as plt
    import numpy as np
    import pandas as pd
    import math

    # Array (Pole) podobna struktura ako List (Zoznam)
    # Od, Do, Krok
    t = np.arange(0, 10, 0.5);
    # RGB
    # CMYK
    # HSV, HSB, HSL
    
    # x - krizik, o - gulicka, s - stvorec, d - disc, p - pentauholnik
    
    
    plt.title("Bodovy graf XY")
    plt.xlabel("X os")
    plt.ylabel("Y os")
    plt.plot(t, t, "yo", t, t**2, "rd", t, t**3, "gp", t, t**4, "b--")
    
    
    plt.show()
    
except:
    print("Moduly neboli nacitane...")
    
finally:
    print("Sme v casti finally")
# Out:
# Sme v casti finally

# %% [markdown]
# ## VII. Snippety (Útržky, kúsky kód)

# %%
# Silly example data
bp_x = np.linspace(0, 2*np.pi, num=40, endpoint=True)
bp_y = np.sin(bp_x)

# Make the plot
plt.plot(bp_x, bp_y, linewidth=3, linestyle="--",
         color="blue", label=r"Legend label $\sin(x)$")
plt.xlabel(r"Description of $x$ coordinate (units)")
plt.ylabel(r"Description of $y$ coordinate (units)")
plt.title(r"Title here (remove for papers)")
plt.xlim(0, 2*np.pi)
plt.ylim(-1.1, 1.1)
plt.legend(loc="lower left")
plt.show()

# %%
from __future__ import print_function, division
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# Silly example data
bp_x = np.linspace(0, 2*np.pi, num=40, endpoint=True)
bp_y = np.sin(bp_x)

# Make the plot
plt.plot(bp_x, bp_y, linewidth=9, linestyle="-.",
         color="#AA00AA", label=r"Legend label $\sin(x)$")
plt.xlabel(r"Description of $x$ coordinate (units)")
plt.ylabel(r"Description of $y$ coordinate (units)")
plt.title(r"Title here (remove for papers)")
plt.xlim(0, 2*np.pi)
plt.ylim(-1.1, 1.1)
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# ## VIII. Koláčové Grafy (Pie Charts)

# %%
try:
    from matplotlib import pyplot as plt
    import numpy as np
    import pandas as pd
    import math
    
    # Python klasicky sposob cez zoznam/list
    a = [10, 20, 30, 40]
    
    # Python Numpy kniznica
    b = np.array([10, 20, 30, 40])
    menovky = ["Notebooky", "Tlaciarne", "Projektory", "Mysky"]
    
    plt.title("Kolacovy graf XY")
    plt.pie(b, labels = menovky, startangle=180, explode = [0.2, 0, 0, 0.2] , shadow = True, 
            colors = ["pink", "#A100AA", "navy", "b"])
    plt.legend(title = "Produkty ABC")
    plt.show()
    
except:
    print("Moduly neboli nacitane...")
    
finally:
    print("Sme v casti finally")
# Out:
# Sme v casti finally

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import math

# Silly example data
x_min, x_max, y_min, y_max = 0.0, 2*np.pi, 0.0, 2*np.pi
f = [[np.sin(x**2 + y**2) for x in np.linspace(x_min, x_max, num=200)]
     for y in np.linspace(y_min, y_max, num=200)]

# Make the plot
plt.figure()
plt.imshow(f, interpolation="bicubic", origin="lower",
           extent=[x_min, x_max, y_min, y_max])
plt.colorbar()
plt.title(r"Title here (remove for papers)")
plt.xlabel(r"Description of $x$ coordinate (units)")
plt.ylabel(r"Description of $y$ coordinate (units)")
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

x = np.random.randn(10000)  # example data, random normal distribution
num_bins = 50
n, bins, patches = plt.hist(x, num_bins, facecolor="magenta", alpha=0.2)
plt.xlabel(r"Description of $x$ coordinate (units)")
plt.ylabel(r"Description of $y$ coordinate (units)")
plt.title(r"Histogram title here (remove for papers)")
plt.grid()
plt.show();

# %% [markdown]
# ## IX. Snippety

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Silly example data
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Make the plot
fig = plt.figure()
ax = fig.gca(projection="3d")
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
ax.set_zlim(-1.01, 1.01)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_12820/1734144598.py:16: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection="3d")

# %%
from __future__ import print_function, division
from sympy import *
a, s, t, u, v, w, x, y, z = symbols("a, s, t, u, v, w, x, y, z")
k, m, n = symbols("k, m, n", integer=True)
f, g, h = symbols("f, g, h", cls=Function)
init_printing()

expr = x**4 - 4*x**3 + 2*x**2 - x
eqn = Eq(expr, 0)
soln = solve(eqn, x)

soln
# Out:
# ⎡                        ___________
# ⎢   4   ⎛  1   √3⋅ⅈ⎞    ╱ √321   83                  10                4
# ⎢0, ─ + ⎜- ─ - ────⎟⋅3 ╱  ──── + ──  + ──────────────────────────────, ─ + ───
# ⎢   3   ⎝  2    2  ⎠ ╲╱    18    54                       ___________  3
# ⎢                                        ⎛  1   √3⋅ⅈ⎞    ╱ √321   83         ⎛
# ⎢                                      9⋅⎜- ─ - ────⎟⋅3 ╱  ──── + ──       9⋅⎜
# ⎣                                        ⎝  2    2  ⎠ ╲╱    18    54         ⎝
#
#                                                ___________
#            10                 ⎛  1   √3⋅ⅈ⎞    ╱ √321   83           10
# ─────────────────────────── + ⎜- ─ + ────⎟⋅3 ╱  ──── + ── , ─────────────────
#                 ___________   ⎝  2    2  ⎠ ╲╱    18    54         ___________
#   1   √3⋅ⅈ⎞    ╱ √321   83                                       ╱ √321   83
# - ─ + ────⎟⋅3 ╱  ──── + ──                                  9⋅3 ╱  ──── + ──
# ...

# %%
import astropy.constants

astropy.constants.M_earth
astropy.constants.m_e
astropy.constants.c
# Out:
# <<class 'astropy.constants.codata2018.CODATA2018'> name='Speed of light in vacuum' value=299792458.0 uncertainty=0.0 unit='m / s' reference='CODATA 2018'>

# %% [markdown]
# <table>
#   <tr>
#     <th>Header 1</th>
#     <th>Header 2</th>
#   </tr>
#   <tr>
#     <td>row 1, cell 1</td>
#     <td>row 1, cell 2</td>
#   </tr>
#   <tr>
#     <td>row 2, cell 1</td>
#     <td>row 2, cell 2</td>
#   </tr>
# </table>

# %% [markdown]
# <img src="image_file_in_this_directory.svg" />

# %% [markdown]
# ## X. Subploting Viacero grafov

# %%
try:
    from matplotlib import pyplot as plt
    import numpy as np
    import pandas as pd
    import math
    
    skupiny = ["Skupina A.", "Skupina B.", "Skupina C."]
    hodnoty = [1, 10, 100]
    
    # default 6.4, 4.8
    plt.figure(figsize=(12, 4))
    
    # nrows, ncols, index
    plt.subplot(1, 4, 1)
    plt.bar(skupiny, hodnoty)
    
    plt.subplot(1, 4, 2)
    plt.plot(skupiny, hodnoty)
    
    plt.subplot(1, 4, 3)
    plt.scatter(skupiny, hodnoty)
    
    plt.subplot(1, 4, 4)
    plt.pie(hodnoty)
    
    plt.show()

    
except:
    print("Moduly neboli nacitane...")
    
finally:
    print("Sme v casti finally")
# Out:
# Sme v casti finally

# %%
try:
    from matplotlib import pyplot as plt
    import numpy as np
    import pandas as pd
    import math
    
    skupiny = ["Skupina A.", "Skupina B.", "Skupina C."]
    hodnoty = [1, 10, 100]
    
    # default 6.4, 4.8
    plt.figure(figsize=(12, 4))
    
    # nrows, ncols, index
    plt.subplot(1, 3, 1)
    plt.grid()
    plt.title("Stlpcovy graf")
    plt.bar(skupiny, hodnoty)
    
    plt.subplot(1, 3, 2)
    plt.grid()
    plt.title("Ciarovy graf")

    plt.plot(skupiny, hodnoty)
    
    plt.subplot(1, 3, 3)
    plt.grid()
    plt.title("Bodovy graf")
    plt.scatter(skupiny, hodnoty)
    plt.show()

    
except:
    print("Moduly neboli nacitane...")
    
finally:
    print("Sme v casti finally")
# Out:
# Sme v casti finally

# %% [markdown]
# ## XI. Obrázky (Images)

# %%
from PIL import Image
obrazok = Image.open("psicky.png")
print(obrazok.size) 
 
print(obrazok)
obrazok.show()
# Out:
# (1169, 1227)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1169x1227 at 0x24B6A5D9430>

# %%
from IPython.display import Image
obrazok = Image(filename = "excel-grafy.jpg", width = 150, height = 150)
obrazok

# %% [markdown]
# ## XII. Kurzy mien Forex

# %%
# Instalovat a stiahnut modyly
# !pip install forex_python

#Importy
from forex_python.converter import CurrencyRates

# Vytvoris objekt/instanciu triedy
c = CurrencyRates()
# ciastka = int(input("Zadajte ciastku: "))
# z_meny = input("Z meny: ").upper()
# do_meny = input("Do meny: ").upper()
# print("Z: ", z_meny, " Do: ", do_meny, " Ciastka: ", ciastka)

# # Konverzacia napr. z EUR na CZK
# vysledok = c.convert(z_meny, do_meny, ciastka)
# print(vysledok, do_meny)

c.get_rates('EUR')
# Out:
# {'USD': 1.0523,
#  'BGN': 1.9558,
#  'CZK': 24.647,
#  'DKK': 7.4419,
#  'GBP': 0.8467,
#  'HUF': 382.88,
#  'RON': 4.9473,
#  'SEK': 10.4675,
#  'CHF': 1.0486,
#  'ISK': 138.9,
#  'TRY': 16.7811,
#  'AUD': 1.498,
#  'BRL': 5.1974,
#  'CAD': 1.3488,
#  'HKD': 8.2591,
#  'INR': 81.6455,
#  'MXN': 20.9204,
#  'MYR': 4.6254,
#  'NZD': 1.6548,
#  'PHP': 55.077,
#  'SGD': 1.4598,
#  'THB': 36.399,
#  'ZAR': 16.7313}
